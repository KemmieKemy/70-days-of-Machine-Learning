# %% [markdown]
# # Day 66: 70 Days Pre-Bootcamp Online Class with Data Science Nigeria - Machine Learning Stream #DSN70daysofML
# Introduction - 3D Convolutional Neural Network w - Kaggle Lung Cancer Detection Competiton <br>

# %%
import dicom # for reading dicom files
import os # for doing directory operations 
import pandas as pd # for some simple data analysis (right now, just to load in the labels data and quickly reference it)


data_dir = '../input/sample_images/'
patients = os.listdir(data_dir)
labels_df = pd.read_csv('../input/stage1_labels.csv', index_col=0)

labels_df.head()
# Out:
#                                   cancer
# id
# 0015ceb851d7251b8f399e39779d1e7d       1
# 0030a160d58723ff36d73f41b170ec21       0
# 003f41c78e6acfa92430a057ac0b306e       0
# 006b96310a37b36cccb2ab48d10b49a3       1
# 008464bb8521d09a42985dd8add3d0d2       1

# %%
for patient in patients[:1]:
    label = labels_df.get_value(patient, 'cancer')
    path = data_dir + patient
    
    # a couple great 1-liners from: https://www.kaggle.com/gzuidhof/data-science-bowl-2017/full-preprocessing-tutorial
    slices = [dicom.read_file(path + '/' + s) for s in os.listdir(path)]
    slices.sort(key = lambda x: int(x.ImagePositionPatient[2]))
    print(len(slices),label)
    print(slices[0])
# Out:
# 177 0
# (0008, 0000) Group Length                        UL: 340
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.14519.5.2.1.7009.9004.241391890999341943254668683377
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 103e) Series Description                  LO: 'Axial'
# (0010, 0000) Group Length                        UL: 64
# (0010, 0010) Patient's Name                      PN: '0d941a3ad6c889ac451caf89c46cb92a'
# (0010, 0020) Patient ID                          LO: '0d941a3ad6c889ac451caf89c46cb92a'
# (0010, 0030) Patient's Birth Date                DA: '19000101'
# (0018, 0060) KVP                                 DS: ''
# (0020, 0000) Group Length                        UL: 392
# (0020, 000d) Study Instance UID                  UI: 2.25.86849464491871006885540678772833603989746112005429227382494
# (0020, 000e) Series Instance UID                 UI: 2.25.31509905657405561568061234063776185722965815794182614617980
# (0020, 0011) Series Number                       IS: '2'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '177'
# (0020, 0032) Image Position (Patient)            DS: ['-129.500000', '-118.099998', '-327.500000']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 0052) Frame of Reference UID              UI: 2.25.11988303469948639268316411162744703040987932600624430221382
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: '-327.500000'
# (0028, 0000) Group Length                        UL: 198
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.505859', '0.505859']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 US or SS: b'0\xf8'
# (0028, 0301) Burned In Annotation                CS: 'NO'
# (0028, 0303) Longitudinal Temporal Information M CS: 'MODIFIED'
# (0028, 1050) Window Center                       DS: '40'
# (0028, 1051) Window Width                        DS: '400'
# (0028, 1052) Rescale Intercept                   DS: '-1024'
# (0028, 1053) Rescale Slope                       DS: '1'
# (7fe0, 0010) Pixel Data                          OB or OW: Array of 524288 bytes

# %%
for patient in patients[:3]:
    label = labels_df.get_value(patient, 'cancer')
    path = data_dir + patient
    
    # a couple great 1-liners from: https://www.kaggle.com/gzuidhof/data-science-bowl-2017/full-preprocessing-tutorial
    slices = [dicom.read_file(path + '/' + s) for s in os.listdir(path)]
    slices.sort(key = lambda x: int(x.ImagePositionPatient[2]))
    print(slices[0].pixel_array.shape, len(slices))
# Out:
# (512, 512) 177
# (512, 512) 110
# (512, 512) 126

# %%
len(patients)
# Out:
# 20

# %%
import matplotlib.pyplot as plt

for patient in patients[:1]:
    label = labels_df.get_value(patient, 'cancer')
    path = data_dir + patient
    slices = [dicom.read_file(path + '/' + s) for s in os.listdir(path)]
    slices.sort(key = lambda x: int(x.ImagePositionPatient[2]))
    
    #          the first slice
    plt.imshow(slices[0].pixel_array)
    plt.show()
